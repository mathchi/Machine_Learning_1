# %% [markdown]
# # Doğrusal Regresyon Modeli

# %% [markdown]
# # PROJE_3(MINI)

# %%
import pandas as pd
df = pd.read_csv("Advertising.csv", index_col = 0)
df.head()
# Out:
#       TV  radio  newspaper  sales
# 1  230.1   37.8       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9       69.3    9.3
# 4  151.5   41.3       58.5   18.5
# 5  180.8   10.8       58.4   12.9

# %%
df.describe().T
# Out:
#            count      mean        std  min     25%     50%      75%    max
# TV         200.0  147.0425  85.854236  0.7  74.375  149.75  218.825  296.4
# radio      200.0   23.2640  14.846809  0.0   9.975   22.90   36.525   49.6
# newspaper  200.0   30.5540  21.778621  0.3  12.750   25.75   45.100  114.0
# sales      200.0   14.0225   5.217457  1.6  10.375   12.90   17.400   27.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200 entries, 1 to 200
# Data columns (total 4 columns):
# TV           200 non-null float64
# radio        200 non-null float64
# newspaper    200 non-null float64
# sales        200 non-null float64
# dtypes: float64(4)
# memory usage: 7.8 KB

# %%
import seaborn as sns
sns.jointplot(x = "TV", y = "sales", data = df, kind = "reg");

# %%
df.head()
# Out:
#       TV  radio  newspaper  sales
# 1  230.1   37.8       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9       69.3    9.3
# 4  151.5   41.3       58.5   18.5
# 5  180.8   10.8       58.4   12.9

# %%
from sklearn.linear_model import LinearRegression

# %%
X = df[["TV"]]

# %%
X.head()
# Out:
#       TV
# 1  230.1
# 2   44.5
# 3   17.2
# 4  151.5
# 5  180.8

# %%
y = df[["sales"]]

# %%
#model

# %%
reg_model = LinearRegression()

# %%
reg_model.fit(X, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
reg_model
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
reg_model.intercept_
# Out:
# array([7.03259355])

# %%
reg_model.coef_
# Out:
# array([[0.04753664]])

# %%
reg_model.score(X, y)
# Out:
# 0.611875050850071

# %%
#tahmin

# %%
#y_hat = 7.03 + 0.04*xi

# %%
7.03 + 0.04*40
# Out:
# 8.63

# %%
import seaborn as sns
import matplotlib.pyplot as plt
g = sns.regplot(df["TV"], df["sales"], ci=None, scatter_kws={'color':'r', 's':9})
g.set_title("Model Denklemi: Sales = 7.03 + TV*0.05")
g.set_ylabel("Satış Sayısı")
g.set_xlabel("TV Harcamaları")
plt.xlim(-10,310)
plt.ylim(bottom=0);

# %% [markdown]
# Sales = 7.03 + 0.05*TV

# %%
reg_model.intercept_ + reg_model.coef_*500
# Out:
# array([[30.80091377]])

# %%
reg_model.predict([[165]])
# Out:
# array([[14.87613922]])

# %%
yeni_veri = [[5],[15],[30]]

# %%
reg_model.predict(yeni_veri)
# Out:
# array([[7.27027675],
#        [7.74564316],
#        [8.45869276]])

# %% [markdown]
# # Çoklu Doğrusal Regresyon

# %%
import pandas as pd
df = pd.read_csv("Advertising.csv", index_col = 0)
df.head()
# Out:
#       TV  radio  newspaper  sales
# 1  230.1   37.8       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9       69.3    9.3
# 4  151.5   41.3       58.5   18.5
# 5  180.8   10.8       58.4   12.9

# %%
X = df.drop('sales', axis=1)
y = df[["sales"]]

# %% [markdown]
# # Model

# %%
reg_model = LinearRegression()

# %%
reg_model.fit(X, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
reg_model.intercept_
# Out:
# array([2.93888937])

# %%
reg_model.coef_
# Out:
# array([[ 0.04576465,  0.18853002, -0.00103749]])

# %% [markdown]
# # Tahmin

# %% [markdown]
# Sales = 2.94 + TV * 0.04 + radio * 0.19 - newspaper * 0.001
#
# 30 birim TV, 10 birim radio, 40 birim gazete

# %%
2.94 + 40 * 0.04 + 10 * 0.19 - 40 * 0.001
# Out:
# 6.3999999999999995

# %%
yeni_veri = [[40],[10],[40]]
import pandas as pd
yeni_veri = pd.DataFrame(yeni_veri).T

# %%
reg_model.predict(yeni_veri)
# Out:
# array([[6.61327564]])

# %%
from sklearn.metrics import mean_squared_error

# %%
y.head()
# Out:
#    sales
# 1   22.1
# 2   10.4
# 3    9.3
# 4   18.5
# 5   12.9

# %% [markdown]
# # Tahmin Başarını Değerlendirme

# %%
reg_model
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
reg_model.predict(X)
# Out:
# array([[20.52397441],
#        [12.33785482],
#        [12.30767078],
#        [17.59782951],
#        [13.18867186],
#        [12.47834763],
#        [11.72975995],
#        [12.12295317],
#        [ 3.72734086],
#        [12.55084872],
#        [ 7.0322992 ],
#        [17.28512918],
#        [10.57712073],
#        [ 8.82630048],
#        [18.43436638],
#        [20.81929952],
#        [12.82365674],
#        [23.22495716],
#        [ 9.95168206],
#        [14.16607293],
#        [18.10076728],
#        [14.7405382 ],
#        [ 6.4891503 ],
#        [16.5459329 ],
#        [ 8.14651887],
#        [15.6100386 ],
#        [14.98951429],
#        [17.05167344],
#        [19.41053803],
#        [ 9.14402389],
#        [21.6339338 ],
#        [11.3460929 ],
#        [ 7.63888314],
#        [18.86426829],
#        [ 7.57483051],
#        [17.00682618],
#        [23.40590052],
#        [15.62347779],
#        [ 9.90868103],
#        [20.44761039],
#        [16.37766467],
#        [17.2959832 ],
#        [21.59580326],
#        [13.96385684],
#        [ 8.88787996],
#        [15.16152314],
#        [ 8.87338673],
#        [21.7226299 ],
#        [16.26362018],
#        [ 8.1681656 ],
#        [12.63121132],
#        [ 9.33981296],
#        [20.66297563],
#        [19.94469957],
#        [20.37443008],
#        [21.2926106 ],
#        [ 8.52771254],
#        [12.77458802],
#        [21.89805198],
#        [18.13348698],
#        [ 5.74215558],
#        [22.89067208],
#        [16.78426073],
#        [13.21069202],
#        [16.97773556],
#        [ 7.84904532],
#        [ 9.01603163],
#        [12.0370073 ],
#        [18.97657924],
#        [21.10891244],
#        [17.77949782],
#        [10.62693815],
#        [10.36684881],
#        [ 9.90298206],
#        [17.32931197],
#        [11.85832174],
#        [ 4.47758904],
#        [13.81190223],
#        [ 8.81331353],
#        [ 9.67530328],
#        [11.44592364],
#        [14.64794093],
#        [10.17840799],
#        [14.42184212],
#        [20.78136464],
#        [15.18140789],
#        [11.59870739],
#        [15.59378475],
#        [11.71127101],
#        [16.92225511],
#        [ 9.99922965],
#        [ 4.49631598],
#        [19.15639616],
#        [21.22757378],
#        [10.48212385],
#        [16.31492112],
#        [12.63571716],
#        [15.33707782],
#        [24.11860723],
#        [16.94035021],
#        [13.87595844],
#        [23.24248685],
#        [17.64409385],
#        [14.76221142],
#        [20.30110878],
#        [17.93641467],
#        [ 6.12602215],
#        [ 7.10850249],
#        [ 3.58725841],
#        [19.69293106],
#        [14.7598741 ],
#        [21.14027498],
#        [13.88060985],
#        [16.40377623],
#        [15.30509593],
#        [12.91968895],
#        [11.97874744],
#        [ 6.5707774 ],
#        [15.56609348],
#        [ 6.82006767],
#        [14.41010605],
#        [ 7.83807642],
#        [13.6264571 ],
#        [15.0827909 ],
#        [19.45441306],
#        [ 9.12734958],
#        [10.57717411],
#        [ 6.599669  ],
#        [22.25549161],
#        [ 7.88410649],
#        [10.4276871 ],
#        [15.57779819],
#        [ 8.44915012],
#        [19.26692307],
#        [11.8368039 ],
#        [14.00141385],
#        [11.45348627],
#        [20.85125198],
#        [ 9.76842795],
#        [19.67547632],
#        [ 9.48964097],
#        [18.39902932],
#        [19.24986927],
#        [ 8.76480262],
#        [10.09133403],
#        [ 9.70853872],
#        [15.29422368],
#        [23.26086103],
#        [12.26335941],
#        [ 9.8272711 ],
#        [18.36720534],
#        [10.0095377 ],
#        [16.3600003 ],
#        [18.22390132],
#        [15.50161696],
#        [ 5.3075589 ],
#        [15.38485192],
#        [10.0143112 ],
#        [10.38419866],
#        [12.39914823],
#        [14.21383298],
#        [13.55914568],
#        [14.94678206],
#        [17.35163608],
#        [11.0682946 ],
#        [14.22372138],
#        [10.82439531],
#        [13.36324677],
#        [17.1861428 ],
#        [17.9415563 ],
#        [ 7.39497997],
#        [14.35827373],
#        [ 7.60769238],
#        [11.97093887],
#        [13.74435742],
#        [24.78687031],
#        [19.9793727 ],
#        [12.1620464 ],
#        [16.01099722],
#        [12.38455495],
#        [10.5871997 ],
#        [13.92809918],
#        [ 6.55467   ],
#        [24.13310013],
#        [18.53852096],
#        [20.80301059],
#        [ 9.69137313],
#        [17.07644223],
#        [18.64430648],
#        [ 6.05162411],
#        [12.4891591 ],
#        [ 8.42401933],
#        [ 4.46622956],
#        [18.48695797],
#        [16.49530044],
#        [ 5.37034248],
#        [ 8.16531236],
#        [12.78592082],
#        [23.76732149],
#        [15.17319554]])

# %%
y_pred = reg_model.predict(X)

# %%
mse = mean_squared_error(y, y_pred)

# %%
mse
# Out:
# 2.784126314510936

# %%
import numpy as np
rmse = np.sqrt(mse)
rmse
# Out:
# 1.6685701407225697

# %%
df.describe().T
# Out:
#            count      mean        std  min     25%     50%      75%    max
# TV         200.0  147.0425  85.854236  0.7  74.375  149.75  218.825  296.4
# radio      200.0   23.2640  14.846809  0.0   9.975   22.90   36.525   49.6
# newspaper  200.0   30.5540  21.778621  0.3  12.750   25.75   45.100  114.0
# sales      200.0   14.0225   5.217457  1.6  10.375   12.90   17.400   27.0

# %% [markdown]
# # Model Doğrulama - Holdout Yöntemi (Model Validation)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    test_size = 0.20, random_state = 1)

# %%
X_train.head()
# Out:
#         TV  radio  newspaper
# 109   13.1    0.4       25.6
# 108   90.4    0.3       23.2
# 190   18.7   12.1       23.4
# 15   204.1   32.9       46.0
# 57     7.3   28.1       41.4

# %%
y_train.head()
# Out:
#      sales
# 109    5.3
# 108    8.7
# 190    6.7
# 15    19.0
# 57     5.5

# %%
X_test.head()
# Out:
#         TV  radio  newspaper
# 59   210.8   49.6       37.7
# 41   202.5   22.3       31.6
# 35    95.7    1.4        7.4
# 103  280.2   10.1       21.4
# 185  253.8   21.3       30.0

# %%
y_test.head()
# Out:
#      sales
# 59    23.8
# 41    16.6
# 35     9.5
# 103   14.8
# 185   17.6

# %%
X_train.shape
# Out:
# (160, 3)

# %%
X_test.shape
# Out:
# (40, 3)

# %%
reg_model = LinearRegression()
reg_model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred = reg_model.predict(X_train)

# %%
#egitim hatasi
np.sqrt(mean_squared_error(y_train, y_pred))
# Out:
# 1.7369025901470923

# %%
y_pred = reg_model.predict(X_test)

# %%
#test hatasi
np.sqrt(mean_squared_error(y_test, y_pred))
# Out:
# 1.4113417558581578

# %% [markdown]
# # Model Doğrulama - K-Fold CV

# %%
from sklearn.model_selection import cross_val_score

# %%
reg_model = LinearRegression()

# %%
#1.yol
-cross_val_score(reg_model, X, y, cv = 10, scoring = "neg_mean_squared_error")
# Out:
# array([3.56038438, 3.29767522, 2.08943356, 2.82474283, 1.3027754 ,
#        1.74163618, 8.17338214, 2.11409746, 3.04273109, 2.45281793])

# %%
#mse
np.mean(-cross_val_score(reg_model, X, y, cv = 10, scoring = "neg_mean_squared_error"))
# Out:
# 3.059967618118513

# %%
np.std(-cross_val_score(reg_model, X, y, cv = 10, scoring = "neg_mean_squared_error"))
# Out:
# 1.8314070401702731

# %%
#rmse
np.sqrt(np.mean(-cross_val_score(reg_model, X, y, cv = 10, scoring = "neg_mean_squared_error")))
# Out:
# 1.7492763126843378

# %%
#2.yol
X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    test_size = 0.20, random_state = 1)

# %%
reg_model = LinearRegression()
reg_model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
np.sqrt(np.mean(-cross_val_score(reg_model, X_train, y_train, cv = 10, scoring = "neg_mean_squared_error")))
# Out:
# 1.7854163438661466

# %%
#test
y_pred = reg_model.predict(X_test)

# %%
#test hatasi
np.sqrt(mean_squared_error(y_test, y_pred))
# Out:
# 1.4113417558581578

# %% [markdown]
# # PROJE 3 (Maaş Tahmin Modeli Geliştirmek)

# %% [markdown]
# # Ridge Regresyon

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn import model_selection
import matplotlib.pyplot as plt
from sklearn.linear_model import RidgeCV

# %%
df = pd.read_csv("Hitters.csv")

# %%
df.head()
# Out:
#    AtBat  Hits  HmRun  Runs  RBI  Walks  Years  CAtBat  CHits  CHmRun  CRuns  \
# 0    293    66      1    30   29     14      1     293     66       1     30
# 1    315    81      7    24   38     39     14    3449    835      69    321
# 2    479   130     18    66   72     76      3    1624    457      63    224
# 3    496   141     20    65   78     37     11    5628   1575     225    828
# 4    321    87     10    39   42     30      2     396    101      12     48
#
#    CRBI  CWalks League Division  PutOuts  Assists  Errors  Salary NewLeague
# 0    29      14      A        E      446       33      20     NaN         A
# 1   414     375      N        W      632       43      10   475.0         N
# 2   266     263      A        W      880       82      14   480.0         A
# 3   838     354      N        E      200       11       3   500.0         N
# 4    46      33      N        E      805       40       4    91.5         N

# %%
df.shape
# Out:
# (322, 20)

# %%
df = df.dropna()

# %%
df = pd.get_dummies(df, columns = ['League', 'Division', 'NewLeague'], drop_first = True)

# %%
df.head()
# Out:
#    AtBat  Hits  HmRun  Runs  RBI  Walks  Years  CAtBat  CHits  CHmRun  CRuns  \
# 1    315    81      7    24   38     39     14    3449    835      69    321
# 2    479   130     18    66   72     76      3    1624    457      63    224
# 3    496   141     20    65   78     37     11    5628   1575     225    828
# 4    321    87     10    39   42     30      2     396    101      12     48
# 5    594   169      4    74   51     35     11    4408   1133      19    501
#
#    CRBI  CWalks  PutOuts  Assists  Errors  Salary  League_N  Division_W  \
# 1   414     375      632       43      10   475.0         1           1
# 2   266     263      880       82      14   480.0         0           1
# 3   838     354      200       11       3   500.0         1           0
# 4    46      33      805       40       4    91.5         1           0
# 5   336     194      282      421      25   750.0         0           1
#
#    NewLeague_N
# 1            1
# 2            0
# 3            1
# 4            1
# 5            0

# %%
y = df["Salary"]
X = df.drop('Salary', axis=1)

# %%
cols = X.columns

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X = scaler.fit_transform(X)

# %%
X.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-79-ae5cd47bda90> in <module>
# ----> 1 X.head()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'head'

# %%
X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    test_size=0.70, 
                                                    random_state=46)

# %%
ridge_model = Ridge().fit(X_train, y_train)

# %%
ridge_model.coef_

# %%
ridge_model.intercept_

# %% [markdown]
# # Tahmin

# %%
y_pred = ridge_model.predict(X_test)
np.sqrt(mean_squared_error(y_test, y_pred))

# %%
ridge_model

# %%
alphas = 10**np.linspace(10,-2,100)*0.5

# %%
ridge_model = Ridge()
coefs = []

for i in alphas:
    ridge_model.set_params(alpha = i)
    ridge_model.fit(X_train, y_train)
    y_pred = ridge_model.predict(X_test)
    print(np.sqrt(mean_squared_error(y_test, y_pred)))

# %%
ridge_model = Ridge()
coefs = []

for i in alphas:
    ridge_model.set_params(alpha = i)
    ridge_model.fit(X_train, y_train)
    coefs.append(ridge_model.coef_)

# %%
coefs

# %%
ax = plt.gca()
ax.plot(alphas, coefs) 
ax.set_xscale("log")

# %%
ridge_model = Ridge().fit(X_train, y_train)
y_pred = ridge_model.predict(X_test)
np.sqrt(mean_squared_error(y_test, y_pred))

# %% [markdown]
# # Model Tuning

# %%
# ?Ridge

# %%
alphas1 = np.random.randint(0,1000,100)
alphas2 = 10**np.linspace(10,-2,100)*0.5
alphas3 = np.linspace(0,1,1000)

# %%
ridge_cv = RidgeCV(alphas = alphas2, scoring = "neg_mean_squared_error", cv = 10, normalize = True)

# burada normalize yapildiktan sonra degerlerin '0' yaklasmasi iyidir

# %%
ridge_cv.fit(X_train, y_train)
# Out:
# RidgeCV(alphas=array([5.00000000e+09, 3.78231664e+09, 2.86118383e+09, 2.16438064e+09,
#        1.63727458e+09, 1.23853818e+09, 9.36908711e+08, 7.08737081e+08,
#        5.36133611e+08, 4.05565415e+08, 3.06795364e+08, 2.32079442e+08,
#        1.75559587e+08, 1.32804389e+08, 1.00461650e+08, 7.59955541e+07,
#        5.74878498e+07, 4.34874501e+07, 3.28966612e+07, 2.48851178e+07,
#        1.88246790e+07, 1.42401793e+0...
#        3.28966612e-01, 2.48851178e-01, 1.88246790e-01, 1.42401793e-01,
#        1.07721735e-01, 8.14875417e-02, 6.16423370e-02, 4.66301673e-02,
#        3.52740116e-02, 2.66834962e-02, 2.01850863e-02, 1.52692775e-02,
#        1.15506485e-02, 8.73764200e-03, 6.60970574e-03, 5.00000000e-03]),
#         cv=10, fit_intercept=True, gcv_mode=None, normalize=True,
#         scoring='neg_mean_squared_error', store_cv_values=False)

# %%
ridge_cv.fit(X, y)
# Out:
# RidgeCV(alphas=array([5.00000000e+09, 3.78231664e+09, 2.86118383e+09, 2.16438064e+09,
#        1.63727458e+09, 1.23853818e+09, 9.36908711e+08, 7.08737081e+08,
#        5.36133611e+08, 4.05565415e+08, 3.06795364e+08, 2.32079442e+08,
#        1.75559587e+08, 1.32804389e+08, 1.00461650e+08, 7.59955541e+07,
#        5.74878498e+07, 4.34874501e+07, 3.28966612e+07, 2.48851178e+07,
#        1.88246790e+07, 1.42401793e+0...
#        3.28966612e-01, 2.48851178e-01, 1.88246790e-01, 1.42401793e-01,
#        1.07721735e-01, 8.14875417e-02, 6.16423370e-02, 4.66301673e-02,
#        3.52740116e-02, 2.66834962e-02, 2.01850863e-02, 1.52692775e-02,
#        1.15506485e-02, 8.73764200e-03, 6.60970574e-03, 5.00000000e-03]),
#         cv=10, fit_intercept=True, gcv_mode=None, normalize=True,
#         scoring='neg_mean_squared_error', store_cv_values=False)

# %%
ridge_cv.alpha_
# Out:
# 0.3289666123287841

# %% [markdown]
# # Tuned Model

# %%
ridge_tuned = Ridge(alpha = 0.3289666123287841).fit(X_train, y_train)
y_pred = ridge_tuned.predict(X_test)
np.sqrt(mean_squared_error(y_test, y_pred))
# Out:
# 384.0918730232824

# %%
ridge_tuned = Ridge(alpha = 0.011).fit(X, y)
y_pred = ridge_tuned.predict(X)
np.sqrt(mean_squared_error(y, y_pred))
# Out:
# 303.34471923970403

# %%
df.shape
# Out:
# (263, 20)

# %%
df.corr()
# Out:
#                 AtBat      Hits     HmRun      Runs       RBI     Walks  \
# AtBat        1.000000  0.963969  0.555102  0.899829  0.796015  0.624448
# Hits         0.963969  1.000000  0.530627  0.910630  0.788478  0.587311
# HmRun        0.555102  0.530627  1.000000  0.631076  0.849107  0.440454
# Runs         0.899829  0.910630  0.631076  1.000000  0.778692  0.697015
# RBI          0.796015  0.788478  0.849107  0.778692  1.000000  0.569505
# Walks        0.624448  0.587311  0.440454  0.697015  0.569505  1.000000
# Years        0.012725  0.018598  0.113488 -0.011975  0.129668  0.134793
# CAtBat       0.207166  0.206678  0.217464  0.171811  0.278126  0.269450
# CHits        0.225341  0.235606  0.217496  0.191327  0.292137  0.270795
# CHmRun       0.212422  0.189364  0.492526  0.229701  0.442190  0.349582
# CRuns        0.237278  0.238896  0.258347  0.237831  0.307226  0.332977
# CRBI         0.221393  0.219384  0.349858  0.202335  0.387777  0.312697
# CWalks       0.132926  0.122971  0.227183  0.163700  0.233619  0.429140
# PutOuts      0.309607  0.299688  0.250931  0.271160  0.312065  0.280855
# Assists      0.342117  0.303975 -0.161602  0.179258  0.062902  0.102523
# Errors       0.325577  0.279876 -0.009743  0.192609  0.150155  0.081937
# Salary       0.394771  0.438675  0.343028  0.419859  0.449457  0.443867
# League_N    -0.153176 -0.153522 -0.222965 -0.206001 -0.185858 -0.065760
# Division_W  -0.056341 -0.083266 -0.034851 -0.107672 -0.090157 -0.072732
# NewLeague_N -0.089838 -0.094990 -0.199424 -0.154911 -0.143549 -0.028461
#
#                 Years    CAtBat     CHits    CHmRun     CRuns      CRBI  \
# AtBat        0.012725  0.207166  0.225341  0.212422  0.237278  0.221393
# Hits         0.018598  0.206678  0.235606  0.189364  0.238896  0.219384
# HmRun        0.113488  0.217464  0.217496  0.492526  0.258347  0.349858
# Runs        -0.011975  0.171811  0.191327  0.229701  0.237831  0.202335
# RBI          0.129668  0.278126  0.292137  0.442190  0.307226  0.387777
# Walks        0.134793  0.269450  0.270795  0.349582  0.332977  0.312697
# Years        1.000000  0.915681  0.897844  0.722371  0.876649  0.863809
# CAtBat       0.915681  1.000000  0.995057  0.801676  0.982747  0.950730
# CHits        0.897844  0.995057  1.000000  0.786652  0.984542  0.946797
# CHmRun       0.722371  0.801676  0.786652  1.000000  0.825625  0.927903
# CRuns        0.876649  0.982747  0.984542  0.825625  1.000000  0.945677
# CRBI         0.863809  0.950730  0.946797  0.927903  0.945677  1.000000
# CWalks       0.837524  0.906712  0.890718  0.810878  0.927768  0.889137
# PutOuts     -0.020019  0.053393  0.067348  0.093822  0.059087  0.095375
# Assists     -0.085118 -0.007897 -0.013144 -0.188886 -0.038895 -0.096559
# Errors      -0.156512 -0.070478 -0.068036 -0.165369 -0.094081 -0.115316
# Salary       0.400657  0.526135  0.548910  0.524931  0.562678  0.566966
# League_N    -0.032893 -0.023704 -0.022853 -0.107299 -0.054318 -0.051421
# Division_W  -0.020316 -0.018623 -0.023642 -0.026987 -0.046812 -0.021564
# NewLeague_N -0.023964 -0.004294  0.000887 -0.100298 -0.034618 -0.037184
#
#                CWalks   PutOuts   Assists    Errors    Salary  League_N  \
# AtBat        0.132926  0.309607  0.342117  0.325577  0.394771 -0.153176
# Hits         0.122971  0.299688  0.303975  0.279876  0.438675 -0.153522
# HmRun        0.227183  0.250931 -0.161602 -0.009743  0.343028 -0.222965
# Runs         0.163700  0.271160  0.179258  0.192609  0.419859 -0.206001
# RBI          0.233619  0.312065  0.062902  0.150155  0.449457 -0.185858
# Walks        0.429140  0.280855  0.102523  0.081937  0.443867 -0.065760
# Years        0.837524 -0.020019 -0.085118 -0.156512  0.400657 -0.032893
# CAtBat       0.906712  0.053393 -0.007897 -0.070478  0.526135 -0.023704
# CHits        0.890718  0.067348 -0.013144 -0.068036  0.548910 -0.022853
# CHmRun       0.810878  0.093822 -0.188886 -0.165369  0.524931 -0.107299
# CRuns        0.927768  0.059087 -0.038895 -0.094081  0.562678 -0.054318
# CRBI         0.889137  0.095375 -0.096559 -0.115316  0.566966 -0.051421
# CWalks       1.000000  0.058160 -0.066243 -0.129936  0.489822 -0.028988
# PutOuts      0.058160  1.000000 -0.043390  0.075306  0.300480  0.039525
# Assists     -0.066243 -0.043390  1.000000  0.703505  0.025436  0.052060
# Errors      -0.129936  0.075306  0.703505  1.000000 -0.005401  0.091774
# Salary       0.489822  0.300480  0.025436 -0.005401  1.000000 -0.014282
# League_N    -0.028988  0.039525  0.052060  0.091774 -0.014282  1.000000
# Division_W  -0.050494 -0.025351 -0.017486 -0.000557 -0.192514 -0.002723
# NewLeague_N -0.025703  0.055048  0.044136  0.063173 -0.002834  0.862652
#
#              Division_W  NewLeague_N
# AtBat         -0.056341    -0.089838
# Hits          -0.083266    -0.094990
# HmRun         -0.034851    -0.199424
# Runs          -0.107672    -0.154911
# RBI           -0.090157    -0.143549
# Walks         -0.072732    -0.028461
# Years         -0.020316    -0.023964
# CAtBat        -0.018623    -0.004294
# CHits         -0.023642     0.000887
# CHmRun        -0.026987    -0.100298
# CRuns         -0.046812    -0.034618
# CRBI          -0.021564    -0.037184
# CWalks        -0.050494    -0.025703
# PutOuts       -0.025351     0.055048
# Assists       -0.017486     0.044136
# Errors        -0.000557     0.063173
# Salary        -0.192514    -0.002834
# League_N      -0.002723     0.862652
# Division_W     1.000000    -0.002436
# NewLeague_N   -0.002436     1.000000

# %%
df.head()
# Out:
#    AtBat  Hits  HmRun  Runs  RBI  Walks  Years  CAtBat  CHits  CHmRun  CRuns  \
# 1    315    81      7    24   38     39     14    3449    835      69    321
# 2    479   130     18    66   72     76      3    1624    457      63    224
# 3    496   141     20    65   78     37     11    5628   1575     225    828
# 4    321    87     10    39   42     30      2     396    101      12     48
# 5    594   169      4    74   51     35     11    4408   1133      19    501
#
#    CRBI  CWalks  PutOuts  Assists  Errors  Salary  League_N  Division_W  \
# 1   414     375      632       43      10   475.0         1           1
# 2   266     263      880       82      14   480.0         0           1
# 3   838     354      200       11       3   500.0         1           0
# 4    46      33      805       40       4    91.5         1           0
# 5   336     194      282      421      25   750.0         0           1
#
#    NewLeague_N
# 1            1
# 2            0
# 3            1
# 4            1
# 5            0

# %% [markdown]
# # Lasso Regresyon

# %%
#Veriyi Anlama
#Veriyi Hazırlama (eksik veri, aykiri veri, label encoding, one hot encoding)
#Modelleme

# %%
#Model
#Tahmin
#Tahmin Başarısını Değerlendir
#Model Tuning (Hiperparametre optimizasyonu, veri hazırlama gözden geçilebilir, yeni değişkenler oluşturulabilir)

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import Ridge, Lasso
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn import model_selection
import matplotlib.pyplot as plt
from sklearn.linear_model import RidgeCV, LassoCV

# %% [markdown]
# ## Model

# %%
df = pd.read_csv("Hitters.csv")
df = df.dropna()
df = pd.get_dummies(df, columns = ['League', 'Division', 'NewLeague'], drop_first = True)
y = df["Salary"]
X = df.drop('Salary', axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    test_size=0.20, 
                                                    random_state=46)

# %%
X_train.head()
# Out:
#      AtBat  Hits  HmRun  Runs  RBI  Walks  Years  CAtBat  CHits  CHmRun  \
# 247    341   110      9    45   49     46      9    2331    658      50
# 204    489   131     19    77   55     34      7    2051    549      62
# 142    232    55      9    34   23     45     12    4405   1213     194
# 149    210    70     13    32   51     28     15    4040   1130      97
# 155    399   102      3    56   34     34      5     670    167       4
#
#      CRuns  CRBI  CWalks  PutOuts  Assists  Errors  League_N  Division_W  \
# 247    249   322     274      251        9       4         0           0
# 204    300   263     153      310        9       9         0           1
# 142    702   705     625      623       35       3         1           0
# 149    544   462     551        0        0       0         0           0
# 155     89    48      54      211        9       3         0           1
#
#      NewLeague_N
# 247            0
# 204            0
# 142            1
# 149            0
# 155            0

# %%
lasso_model = Lasso().fit(X_train, y_train)

# %%
lasso_model
# Out:
# Lasso(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=1000,
#       normalize=False, positive=False, precompute=False, random_state=None,
#       selection='cyclic', tol=0.0001, warm_start=False)

# %%
lasso_model.intercept_
# Out:
# 38.309028534677964

# %%
lasso_model.coef_
# Out:
# array([ -1.3067347 ,   5.42492055,   5.95857377,   0.71986511,
#         -1.27705641,   2.2412296 ,  -0.        ,  -0.3910336 ,
#          1.6211596 ,   2.30085041,   0.44881763,  -0.67661266,
#         -0.08491993,   0.32932779,   0.15372641,  -0.31737035,
#         43.00102617, -49.15897065, -22.7034865 ])

# %% [markdown]
# ## Tahmin

# %%
lasso_model.predict(X_test)
# Out:
# array([ 134.02691115,  360.35606001,  297.92088167,  231.73634366,
#         264.94280581,   96.27664716,  383.79236428,  609.82657799,
#         230.7473563 ,  769.80065093,  191.92021296,  218.00618603,
#         866.58905838,  352.82945235,  368.39272834,  714.71087186,
#        1378.17777923,  538.21550317,  672.2276415 ,  409.1438966 ,
#         541.53245009,  642.43094681,  731.91372111,  395.47345235,
#         292.89861001,  507.68888157,  965.54441857,  265.11559313,
#         500.46234192,  432.02522527,  932.19819857,  549.62911505,
#         927.02011452,  259.76269044,  143.01549823,  375.35665605,
#         116.48149341,  499.96482963,  290.91315969,  174.37683041,
#         223.96256256, 1715.24456176,  230.64910139,  453.8195808 ,
#         513.31728061,  214.67626546,  642.77633249, 1927.1329257 ,
#         593.29036812,  209.76557045,  889.23083895,  587.47856702,
#         112.70294995])

# %%
y_pred = lasso_model.predict(X_test)

# %%
np.sqrt(mean_squared_error(y_test, y_pred))
# Out:
# 478.31797216165194

# %%
df.describe()
# Out:
#             AtBat        Hits       HmRun        Runs         RBI       Walks  \
# count  263.000000  263.000000  263.000000  263.000000  263.000000  263.000000
# mean   403.642586  107.828897   11.619772   54.745247   51.486692   41.114068
# std    147.307209   45.125326    8.757108   25.539816   25.882714   21.718056
# min     19.000000    1.000000    0.000000    0.000000    0.000000    0.000000
# 25%    282.500000   71.500000    5.000000   33.500000   30.000000   23.000000
# 50%    413.000000  103.000000    9.000000   52.000000   47.000000   37.000000
# 75%    526.000000  141.500000   18.000000   73.000000   71.000000   57.000000
# max    687.000000  238.000000   40.000000  130.000000  121.000000  105.000000
#
#             Years        CAtBat        CHits      CHmRun        CRuns  \
# count  263.000000    263.000000   263.000000  263.000000   263.000000
# mean     7.311787   2657.543726   722.186312   69.239544   361.220532
# std      4.793616   2286.582929   648.199644   82.197581   331.198571
# min      1.000000     19.000000     4.000000    0.000000     2.000000
# 25%      4.000000    842.500000   212.000000   15.000000   105.500000
# 50%      6.000000   1931.000000   516.000000   40.000000   250.000000
# 75%     10.000000   3890.500000  1054.000000   92.500000   497.500000
# max     24.000000  14053.000000  4256.000000  548.000000  2165.000000
#
#               CRBI       CWalks      PutOuts     Assists      Errors  \
# count   263.000000   263.000000   263.000000  263.000000  263.000000
# mean    330.418251   260.266160   290.711027  118.760456    8.593156
# std     323.367668   264.055868   279.934575  145.080577    6.606574
# min       3.000000     1.000000     0.000000    0.000000    0.000000
# 25%      95.000000    71.000000   113.500000    8.000000    3.000000
# 50%     230.000000   174.000000   224.000000   45.000000    7.000000
# 75%     424.500000   328.500000   322.500000  192.000000   13.000000
# max    1659.000000  1566.000000  1377.000000  492.000000   32.000000
#
#             Salary    League_N  Division_W  NewLeague_N
# count   263.000000  263.000000  263.000000   263.000000
# mean    535.925882    0.471483    0.509506     0.463878
# std     451.118681    0.500138    0.500863     0.499644
# min      67.500000    0.000000    0.000000     0.000000
# 25%     190.000000    0.000000    0.000000     0.000000
# 50%     425.000000    0.000000    1.000000     0.000000
# 75%     750.000000    1.000000    1.000000     1.000000
# max    2460.000000    1.000000    1.000000     1.000000

# %% [markdown]
# # Model Tuning

# %%
# ?lasso_model
# Out:
# Type:        Lasso
# String form:
# Lasso(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=1000,
#       normalize=False, positive=False, precompute=False, random_state=None,
#       selection='cyclic', tol=0.0001, warm_start=False)
# File:        ~/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py
# Docstring:
# Linear Model trained with L1 prior as regularizer (aka the Lasso)
#
# The optimization objective for Lasso is::
#
#     (1 / (2 * n_samples)) * ||y - Xw||^2_2 + alpha * ||w||_1
#
# Technically the Lasso model is optimizing the same objective function as
# the Elastic Net with ``l1_ratio=1.0`` (no L2 penalty).
#
# Read more in the :ref:`User Guide <lasso>`.
#
# Parameters
# ----------
# alpha : float, optional
#     Constant that multiplies the L1 term. Defaults to 1.0.
#     ``alpha = 0`` is equivalent to an ordinary least square, solved
#     by the :class:`LinearRegression` object. For numerical
#     reasons, using ``alpha = 0`` with the ``Lasso`` object is not advised.
#     Given this, you should use the :class:`LinearRegression` object.
#
# fit_intercept : boolean, optional, default True
#     Whether to calculate the intercept for this model. If set
#     to False, no intercept will be used in calculations
#     (i.e. data is expected to be centered).
#
# normalize : boolean, optional, default False
#     This parameter is ignored when ``fit_intercept`` is set to False.
#     If True, the regressors X will be normalized before regression by
#     subtracting the mean and dividing by the l2-norm.
#     If you wish to standardize, please use
#     :class:`sklearn.preprocessing.StandardScaler` before calling ``fit``
#     on an estimator with ``normalize=False``.
#
# precompute : True | False | array-like, default=False
#     Whether to use a precomputed Gram matrix to speed up
#     calculations. If set to ``'auto'`` let us decide. The Gram
#     matrix can also be passed as argument. For sparse input
#     this option is always ``True`` to preserve sparsity.
#
# copy_X : boolean, optional, default True
#     If ``True``, X will be copied; else, it may be overwritten.
#
# max_iter : int, optional
#     The maximum number of iterations
#
# tol : float, optional
#     The tolerance for the optimization: if the updates are
#     smaller than ``tol``, the optimization code checks the
#     dual gap for optimality and continues until it is smaller
#     than ``tol``.
#
# warm_start : bool, optional
#     When set to True, reuse the solution of the previous call to fit as
#     initialization, otherwise, just erase the previous solution.
#     See :term:`the Glossary <warm_start>`.
#
# positive : bool, optional
#     When set to ``True``, forces the coefficients to be positive.
#
# random_state : int, RandomState instance or None, optional, default None
#     The seed of the pseudo random number generator that selects a random
#     feature to update.  If int, random_state is the seed used by the random
#     number generator; If RandomState instance, random_state is the random
#     number generator; If None, the random number generator is the
#     RandomState instance used by `np.random`. Used when ``selection`` ==
#     'random'.
#
# selection : str, default 'cyclic'
#     If set to 'random', a random coefficient is updated every iteration
#     rather than looping over features sequentially by default. This
#     (setting to 'random') often leads to significantly faster convergence
#     especially when tol is higher than 1e-4.
#
# Attributes
# ----------
# coef_ : array, shape (n_features,) | (n_targets, n_features)
#     parameter vector (w in the cost function formula)
#
# sparse_coef_ : scipy.sparse matrix, shape (n_features, 1) |             (n_targets, n_features)
#     ``sparse_coef_`` is a readonly property derived from ``coef_``
#
# intercept_ : float | array, shape (n_targets,)
#     independent term in decision function.
#
# n_iter_ : int | array-like, shape (n_targets,)
#     number of iterations run by the coordinate descent solver to reach
#     the specified tolerance.
#
# Examples
# --------
# >>> from sklearn import linear_model
# >>> clf = linear_model.Lasso(alpha=0.1)
# >>> clf.fit([[0,0], [1, 1], [2, 2]], [0, 1, 2])
# Lasso(alpha=0.1)
# >>> print(clf.coef_)
# [0.85 0.  ]
# >>> print(clf.intercept_)
# 0.15...
#
# See also
# --------
# lars_path
# lasso_path
# LassoLars
# LassoCV
# LassoLarsCV
# sklearn.decomposition.sparse_encode
#
# Notes
# -----
# The algorithm used to fit the model is coordinate descent.
#
# To avoid unnecessary memory duplication the X argument of the fit method
# should be directly passed as a Fortran-contiguous numpy array.

# %%
alphas1 = np.random.randint(0,1000,100)
alphas2 = 10**np.linspace(10,-2,100)*0.5
alphas3 = np.linspace(0,1,1000)

# %%
lasso_cv_model = LassoCV(alphas = alphas3, cv = 10).fit(X_train, y_train)
# Out:
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6726221.329839558, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6230922.601830419, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3624879.9565231875, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 424439.66970867664, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15806.497214995325, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3557.9659235868603, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3570.947672381997, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3584.1606943123043, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3589.859087239951, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3602.3777389265597, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3615.7233123015612, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3629.228985795751, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3642.8288599811494, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3656.5074855368584, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3670.2704757116735, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3684.1179818809032, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3698.047831600532, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3712.0614791475236, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3726.1602970659733, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3740.3482834734023, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3754.6176690086722, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3768.9752697180957, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3783.4258114024997, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3797.960859529674, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3812.588235432282, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3827.302358869463, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3842.110628142953, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3857.0111122615635, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3872.0032391175628, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3887.088223852217, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3902.268321754411, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3917.5409975647926, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3932.9152639210224, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3948.3812830112875, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3963.9466669373214, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3979.6106079667807, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3995.373248387128, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4011.2366168238223, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4018.6546873673797, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4033.740601282567, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4049.766081765294, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4065.9886598493904, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4082.324316713959, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4098.768198177218, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4115.315081484616, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4131.971779478714, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4148.736920595169, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4165.6113621890545, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4182.592919141054, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4199.688142389059, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4216.895431637764, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4234.21547482349, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4251.649349294603, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4269.2006694749, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4286.865356780589, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4304.649549888447, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4322.550742801279, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4340.5727199018, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4358.7133184969425, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4376.978921746835, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4395.364516764879, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4413.87430491671, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4432.509498685598, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4451.271480757743, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4460.652598436922, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4478.577250570059, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4497.563004858792, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4516.783028904349, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4536.142780179158, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4555.6402395460755, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4575.270247315988, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4595.035844415426, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4614.941149298102, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4634.981777187437, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4655.161831580102, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4675.4857769571245, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4695.9503133147955, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4716.556159615517, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4737.310949102044, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4758.212877467275, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4779.256796019152, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4800.454180922359, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4821.803508948535, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4843.304302345961, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4864.95263207145, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4886.764837667346, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4908.73041921109, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4920.347069308162, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4941.426299389452, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4963.6878833808005, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4986.228058122098, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5008.942451860756, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5031.822412721813, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5054.876316815615, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5078.094338141382, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5101.484211560339, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5125.047920227051, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5148.7887372635305, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5172.697444610298, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5196.7930455785245, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5221.060276966542, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5245.512324102223, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5270.1510141938925, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5294.971217140555, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5319.978101167828, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5345.177145609632, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5370.564995242283, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5384.633203109726, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5409.089465159923, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5434.856494110078, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5460.95395401679, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5487.259521819651, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5513.771846443415, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5540.490002833307, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5567.413970386609, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5594.5444609075785, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5621.8902513720095, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5649.450544819236, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5677.224195629358, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5705.217720808461, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5733.430255461484, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5761.867911064997, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5790.530552431941, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5819.415364127606, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5836.048575017601, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5863.972620699555, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5893.3338182121515, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7522.014724886045, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7396.829655673355, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7448.309462450445, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7486.030587980524, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7541.404128689319, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7595.4478483349085, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7650.131341021508, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7705.499775517732, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7761.567367972806, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7818.337057646364, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7875.8253935631365, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7934.04511122033, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7993.010184673592, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8052.73581972532, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8113.223607534543, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8174.499333690852, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8236.57110769488, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8297.06396226585, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3548.7865883950144, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3559.6954764425755, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3570.878532268107, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3582.147496012971, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3593.4767808951437, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3604.8646054416895, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3616.3084963671863, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3627.81491105631, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3639.376139432192, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3651.0001011788845, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3662.6871994566172, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3674.429947871715, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3686.2351516373456, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3698.098041243851, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3710.024499308318, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3722.0172158833593, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3734.0675208345056, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3746.183469697833, tolerance: 3547.539874726709
#   tol, rng, random, positive)
# ...
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 132825.18184810504, tolerance: 3724.140602819258
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 137363.28819531575, tolerance: 3724.140602819258
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 142138.48434082977, tolerance: 3724.140602819258
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 147167.6008957941, tolerance: 3724.140602819258
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 152469.10772175528, tolerance: 3724.140602819258
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 158062.765892379, tolerance: 3724.140602819258
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 163970.7432434596, tolerance: 3724.140602819258
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 170216.38928101957, tolerance: 3724.140602819258
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 176826.80260830745, tolerance: 3724.140602819258
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 183830.53500885144, tolerance: 3724.140602819258
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 191259.34302281588, tolerance: 3724.140602819258
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 199148.5897268206, tolerance: 3724.140602819258
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 207536.97181303985, tolerance: 3724.140602819258
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 216467.3071800731, tolerance: 3724.140602819258
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 225987.4497310277, tolerance: 3724.140602819258
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 236150.9128421396, tolerance: 3724.140602819258
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 247016.17976251058, tolerance: 3724.140602819258
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 258650.4511733353, tolerance: 3724.140602819258
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 271126.9599860683, tolerance: 3724.140602819258
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 284529.13601490296, tolerance: 3724.140602819258
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 298951.8272276614, tolerance: 3724.140602819258
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 314500.79823151976, tolerance: 3724.140602819258
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 331295.7413500827, tolerance: 3724.140602819258
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 349474.45054347627, tolerance: 3724.140602819258
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 369192.96880160645, tolerance: 3724.140602819258
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 390629.6113914922, tolerance: 3724.140602819258
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 413991.16514338553, tolerance: 3724.140602819258
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 439513.56003669463, tolerance: 3724.140602819258
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 467472.89145730063, tolerance: 3724.140602819258
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 498189.9403642081, tolerance: 3724.140602819258
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 532037.847887829, tolerance: 3724.140602819258
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 569459.0495182853, tolerance: 3724.140602819258
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 610973.147987444, tolerance: 3724.140602819258
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 657200.9070179332, tolerance: 3724.140602819258
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 708883.6693886053, tolerance: 3724.140602819258
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 766913.1984233353, tolerance: 3724.140602819258
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 832374.7181918137, tolerance: 3724.140602819258
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 906593.4314182596, tolerance: 3724.140602819258
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 991202.1169076404, tolerance: 3724.140602819258
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1088236.8296124274, tolerance: 3724.140602819258
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1200255.0988743538, tolerance: 3724.140602819258
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1330507.2296567522, tolerance: 3724.140602819258
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1483177.71687059, tolerance: 3724.140602819258
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1663722.3844171893, tolerance: 3724.140602819258
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1879361.4536548713, tolerance: 3724.140602819258
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2139822.1475745337, tolerance: 3724.140602819258
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2458440.188314243, tolerance: 3724.140602819258
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2853913.272830924, tolerance: 3724.140602819258
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3353103.6162482193, tolerance: 3724.140602819258
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3995724.2084192503, tolerance: 3724.140602819258
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4842483.97861455, tolerance: 3724.140602819258
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5989980.863707133, tolerance: 3724.140602819258
#   tol, rng, random, positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7125932.854246634, tolerance: 3956.6756074595623
#   positive)

# %%
lasso_cv_model.alpha_
# Out:
# 1.0

# %%
lasso_tuned = Lasso(alpha = 1000).fit(X_train, y_train)
# Out:
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 35235.6952349972, tolerance: 3956.6756074595623
#   positive)

# %%
y_pred = lasso_tuned.predict(X_test)

# %%
np.sqrt(mean_squared_error(y_test, y_pred))
# Out:
# 486.62279663894805

# %%
pd.Series(lasso_tuned.coef_, index = X_train.columns)
# Out:
# AtBat          -1.306735
# Hits            5.424921
# HmRun           5.958574
# Runs            0.719865
# RBI            -1.277056
# Walks           2.241230
# Years          -0.000000
# CAtBat         -0.391034
# CHits           1.621160
# CHmRun          2.300850
# CRuns           0.448818
# CRBI           -0.676613
# CWalks         -0.084920
# PutOuts         0.329328
# Assists         0.153726
# Errors         -0.317370
# League_N       43.001026
# Division_W    -49.158971
# NewLeague_N   -22.703486
# dtype: float64

# %%
pd.Series(lasso_tuned.coef_, index = X_train.columns)
# Out:
# AtBat          0.574952
# Hits           0.142422
# HmRun          0.000000
# Runs           0.000000
# RBI            0.000000
# Walks          0.000000
# Years         -0.000000
# CAtBat        -0.381451
# CHits          1.106027
# CHmRun         0.000000
# CRuns          0.979173
# CRBI           0.206466
# CWalks         0.048074
# PutOuts        0.342295
# Assists       -0.000000
# Errors        -0.000000
# League_N       0.000000
# Division_W    -0.000000
# NewLeague_N    0.000000
# dtype: float64

# %% [markdown]
# # ElasticNet Regression

# %%
df = pd.read_csv("Hitters.csv")
df = df.dropna()
df = pd.get_dummies(df, columns = ['League', 'Division', 'NewLeague'], drop_first = True)
y = df["Salary"]
X = df.drop('Salary', axis=1)

# %%
df.head()
# Out:
#    AtBat  Hits  HmRun  Runs  RBI  Walks  Years  CAtBat  CHits  CHmRun  CRuns  \
# 1    315    81      7    24   38     39     14    3449    835      69    321
# 2    479   130     18    66   72     76      3    1624    457      63    224
# 3    496   141     20    65   78     37     11    5628   1575     225    828
# 4    321    87     10    39   42     30      2     396    101      12     48
# 5    594   169      4    74   51     35     11    4408   1133      19    501
#
#    CRBI  CWalks  PutOuts  Assists  Errors  Salary  League_N  Division_W  \
# 1   414     375      632       43      10   475.0         1           1
# 2   266     263      880       82      14   480.0         0           1
# 3   838     354      200       11       3   500.0         1           0
# 4    46      33      805       40       4    91.5         1           0
# 5   336     194      282      421      25   750.0         0           1
#
#    NewLeague_N
# 1            1
# 2            0
# 3            1
# 4            1
# 5            0

# %%
for feature in df:

    Q1 = df[feature].quantile(0.25)
    Q3 = df[feature].quantile(0.75)
    IQR = Q3-Q1
    upper = Q3 + 1.5*IQR
    lower = Q1 - 1.5*IQR

    if df[(df[feature] > upper) | (df[feature] < lower)].any(axis=None):
        print(feature,"yes")
        print(df[(df[feature] > upper) | (df[feature] < lower)].shape[0])
    else:
        print(feature, "no")
# Out:
# AtBat no
# Hits no
# HmRun yes
# 1
# Runs no
# RBI no
# Walks no
# Years yes
# 3
# CAtBat yes
# 4
# CHits yes
# 5
# CHmRun yes
# 23
# CRuns yes
# 8
# CRBI yes
# 22
# CWalks yes
# 20
# PutOuts yes
# 29
# Assists yes
# 5
# Errors yes
# 2
# Salary yes
# 11
# League_N no
# Division_W no
# NewLeague_N no

# %%
cols = X.columns
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X = scaler.fit_transform(X)
X = pd.DataFrame(X, columns = cols)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    test_size=0.20, 
                                                    random_state=46)

# %%
X_train.head()
# Out:
#         AtBat      Hits     HmRun      Runs       RBI     Walks     Years  \
# 241 -1.351063 -1.439380 -1.100605 -1.206112 -1.334962 -0.974043 -0.065166
# 25   0.743792  0.647679  0.958788  1.383016  1.684378  2.255227  1.397893
# 62   1.430741  1.224951  1.988484  1.343787  1.219864  1.563240  0.770868
# 85   1.308315  1.402573  2.560537  1.422245  2.187601  0.502194 -0.274175
# 73   1.097469  0.891909  1.416430  1.383016  2.032763  1.655505  1.397893
#
#        CAtBat     CHits    CHmRun     CRuns      CRBI    CWalks   PutOuts  \
# 241 -0.790254 -0.777763 -0.697693 -0.775091 -0.717015 -0.718132 -0.571618
# 25   1.114460  1.019858  1.179414  1.215420  1.250438  1.987202 -0.084864
# 62   1.033837  1.029132  2.398314  1.366675  1.523093  1.353554  0.043983
# 85   0.089586  0.008986  0.460262 -0.000667  0.218687 -0.137605 -0.618146
# 73   2.028478  2.103377  2.873685  2.340755  2.799614  2.013762  0.004613
#
#       Assists    Errors  League_N  Division_W  NewLeague_N
# 241 -0.778708 -1.151525  1.058758   -1.019196     1.075052
# 25  -0.785614 -0.848219 -0.944503    0.981166    -0.930187
# 62  -0.778708 -0.393260  1.058758    0.981166     1.075052
# 85   1.486415  1.881535 -0.944503    0.981166    -0.930187
# 73  -0.757991 -0.544913 -0.944503   -1.019196    -0.930187

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import Ridge, Lasso, ElasticNet
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn import model_selection
import matplotlib.pyplot as plt
from sklearn.linear_model import RidgeCV, LassoCV,ElasticNetCV

# %% [markdown]
# # Model Tahmin

# %%
enet_model = ElasticNet().fit(X_train, y_train)
y_pred = enet_model.predict(X_test)
np.sqrt(mean_squared_error(y_test, y_pred))
# Out:
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6491601.082958906, tolerance: 3528.10439015266
#   positive)
# 428.4434472100666

# %%
#tum veri

# %%
# ?ElasticNet
# Out:
# Init signature:
# ElasticNet(
#     alpha=1.0,
#     l1_ratio=0.5,
#     fit_intercept=True,
#     normalize=False,
#     precompute=False,
#     max_iter=1000,
#     copy_X=True,
#     tol=0.0001,
#     warm_start=False,
#     positive=False,
#     random_state=None,
#     selection='cyclic',
# )
# Docstring:
# Linear regression with combined L1 and L2 priors as regularizer.
#
# Minimizes the objective function::
#
#         1 / (2 * n_samples) * ||y - Xw||^2_2
#         + alpha * l1_ratio * ||w||_1
#         + 0.5 * alpha * (1 - l1_ratio) * ||w||^2_2
#
# If you are interested in controlling the L1 and L2 penalty
# separately, keep in mind that this is equivalent to::
#
#         a * L1 + b * L2
#
# where::
#
#         alpha = a + b and l1_ratio = a / (a + b)
#
# The parameter l1_ratio corresponds to alpha in the glmnet R package while
# alpha corresponds to the lambda parameter in glmnet. Specifically, l1_ratio
# = 1 is the lasso penalty. Currently, l1_ratio <= 0.01 is not reliable,
# unless you supply your own sequence of alpha.
#
# Read more in the :ref:`User Guide <elastic_net>`.
#
# Parameters
# ----------
# alpha : float, optional
#     Constant that multiplies the penalty terms. Defaults to 1.0.
#     See the notes for the exact mathematical meaning of this
#     parameter. ``alpha = 0`` is equivalent to an ordinary least square,
#     solved by the :class:`LinearRegression` object. For numerical
#     reasons, using ``alpha = 0`` with the ``Lasso`` object is not advised.
#     Given this, you should use the :class:`LinearRegression` object.
#
# l1_ratio : float
#     The ElasticNet mixing parameter, with ``0 <= l1_ratio <= 1``. For
#     ``l1_ratio = 0`` the penalty is an L2 penalty. ``For l1_ratio = 1`` it
#     is an L1 penalty.  For ``0 < l1_ratio < 1``, the penalty is a
#     combination of L1 and L2.
#
# fit_intercept : bool
#     Whether the intercept should be estimated or not. If ``False``, the
#     data is assumed to be already centered.
#
# normalize : boolean, optional, default False
#     This parameter is ignored when ``fit_intercept`` is set to False.
#     If True, the regressors X will be normalized before regression by
#     subtracting the mean and dividing by the l2-norm.
#     If you wish to standardize, please use
#     :class:`sklearn.preprocessing.StandardScaler` before calling ``fit``
#     on an estimator with ``normalize=False``.
#
# precompute : True | False | array-like
#     Whether to use a precomputed Gram matrix to speed up
#     calculations. The Gram matrix can also be passed as argument.
#     For sparse input this option is always ``True`` to preserve sparsity.
#
# max_iter : int, optional
#     The maximum number of iterations
#
# copy_X : boolean, optional, default True
#     If ``True``, X will be copied; else, it may be overwritten.
#
# tol : float, optional
#     The tolerance for the optimization: if the updates are
#     smaller than ``tol``, the optimization code checks the
#     dual gap for optimality and continues until it is smaller
#     than ``tol``.
#
# warm_start : bool, optional
#     When set to ``True``, reuse the solution of the previous call to fit as
#     initialization, otherwise, just erase the previous solution.
#     See :term:`the Glossary <warm_start>`.
#
# positive : bool, optional
#     When set to ``True``, forces the coefficients to be positive.
#
# random_state : int, RandomState instance or None, optional, default None
#     The seed of the pseudo random number generator that selects a random
#     feature to update.  If int, random_state is the seed used by the random
#     number generator; If RandomState instance, random_state is the random
#     number generator; If None, the random number generator is the
#     RandomState instance used by `np.random`. Used when ``selection`` ==
#     'random'.
#
# selection : str, default 'cyclic'
#     If set to 'random', a random coefficient is updated every iteration
#     rather than looping over features sequentially by default. This
#     (setting to 'random') often leads to significantly faster convergence
#     especially when tol is higher than 1e-4.
#
# Attributes
# ----------
# coef_ : array, shape (n_features,) | (n_targets, n_features)
#     parameter vector (w in the cost function formula)
#
# sparse_coef_ : scipy.sparse matrix, shape (n_features, 1) |             (n_targets, n_features)
#     ``sparse_coef_`` is a readonly property derived from ``coef_``
#
# intercept_ : float | array, shape (n_targets,)
#     independent term in decision function.
#
# n_iter_ : array-like, shape (n_targets,)
#     number of iterations run by the coordinate descent solver to reach
#     the specified tolerance.
#
# Examples
# --------
# >>> from sklearn.linear_model import ElasticNet
# >>> from sklearn.datasets import make_regression
#
# >>> X, y = make_regression(n_features=2, random_state=0)
# >>> regr = ElasticNet(random_state=0)
# >>> regr.fit(X, y)
# ElasticNet(random_state=0)
# >>> print(regr.coef_)
# [18.83816048 64.55968825]
# >>> print(regr.intercept_)
# 1.451...
# >>> print(regr.predict([[0, 0]]))
# [1.451...]
#
#
# Notes
# -----
# To avoid unnecessary memory duplication the X argument of the fit method
# should be directly passed as a Fortran-contiguous numpy array.
#
# See also
# --------
# ElasticNetCV : Elastic net model with best model selection by
#     cross-validation.
# SGDRegressor: implements elastic net regression with incremental training.
# SGDClassifier: implements logistic regression with elastic net penalty
#     (``SGDClassifier(loss="log", penalty="elasticnet")``).
# File:           ~/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py
# Type:           ABCMeta
# Subclasses:     Lasso

# %%
enet_model = ElasticNet().fit(X, y)
y_pred = enet_model.predict(X)
np.sqrt(mean_squared_error(y, y_pred))
# Out:
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 12384707.519684685, tolerance: 5331.911278864535
#   positive)
# 306.18811261334486

# %% [markdown]
# # Model Tuning

# %%
alphas1 = np.random.randint(0,1000,100)
alphas2 = 10**np.linspace(10,-2,100)*0.5
alphas3 = np.linspace(0,1,1000)

# %%
# ?ElasticNet
# Out:
# Init signature:
# ElasticNet(
#     alpha=1.0,
#     l1_ratio=0.5,
#     fit_intercept=True,
#     normalize=False,
#     precompute=False,
#     max_iter=1000,
#     copy_X=True,
#     tol=0.0001,
#     warm_start=False,
#     positive=False,
#     random_state=None,
#     selection='cyclic',
# )
# Docstring:
# Linear regression with combined L1 and L2 priors as regularizer.
#
# Minimizes the objective function::
#
#         1 / (2 * n_samples) * ||y - Xw||^2_2
#         + alpha * l1_ratio * ||w||_1
#         + 0.5 * alpha * (1 - l1_ratio) * ||w||^2_2
#
# If you are interested in controlling the L1 and L2 penalty
# separately, keep in mind that this is equivalent to::
#
#         a * L1 + b * L2
#
# where::
#
#         alpha = a + b and l1_ratio = a / (a + b)
#
# The parameter l1_ratio corresponds to alpha in the glmnet R package while
# alpha corresponds to the lambda parameter in glmnet. Specifically, l1_ratio
# = 1 is the lasso penalty. Currently, l1_ratio <= 0.01 is not reliable,
# unless you supply your own sequence of alpha.
#
# Read more in the :ref:`User Guide <elastic_net>`.
#
# Parameters
# ----------
# alpha : float, optional
#     Constant that multiplies the penalty terms. Defaults to 1.0.
#     See the notes for the exact mathematical meaning of this
#     parameter. ``alpha = 0`` is equivalent to an ordinary least square,
#     solved by the :class:`LinearRegression` object. For numerical
#     reasons, using ``alpha = 0`` with the ``Lasso`` object is not advised.
#     Given this, you should use the :class:`LinearRegression` object.
#
# l1_ratio : float
#     The ElasticNet mixing parameter, with ``0 <= l1_ratio <= 1``. For
#     ``l1_ratio = 0`` the penalty is an L2 penalty. ``For l1_ratio = 1`` it
#     is an L1 penalty.  For ``0 < l1_ratio < 1``, the penalty is a
#     combination of L1 and L2.
#
# fit_intercept : bool
#     Whether the intercept should be estimated or not. If ``False``, the
#     data is assumed to be already centered.
#
# normalize : boolean, optional, default False
#     This parameter is ignored when ``fit_intercept`` is set to False.
#     If True, the regressors X will be normalized before regression by
#     subtracting the mean and dividing by the l2-norm.
#     If you wish to standardize, please use
#     :class:`sklearn.preprocessing.StandardScaler` before calling ``fit``
#     on an estimator with ``normalize=False``.
#
# precompute : True | False | array-like
#     Whether to use a precomputed Gram matrix to speed up
#     calculations. The Gram matrix can also be passed as argument.
#     For sparse input this option is always ``True`` to preserve sparsity.
#
# max_iter : int, optional
#     The maximum number of iterations
#
# copy_X : boolean, optional, default True
#     If ``True``, X will be copied; else, it may be overwritten.
#
# tol : float, optional
#     The tolerance for the optimization: if the updates are
#     smaller than ``tol``, the optimization code checks the
#     dual gap for optimality and continues until it is smaller
#     than ``tol``.
#
# warm_start : bool, optional
#     When set to ``True``, reuse the solution of the previous call to fit as
#     initialization, otherwise, just erase the previous solution.
#     See :term:`the Glossary <warm_start>`.
#
# positive : bool, optional
#     When set to ``True``, forces the coefficients to be positive.
#
# random_state : int, RandomState instance or None, optional, default None
#     The seed of the pseudo random number generator that selects a random
#     feature to update.  If int, random_state is the seed used by the random
#     number generator; If RandomState instance, random_state is the random
#     number generator; If None, the random number generator is the
#     RandomState instance used by `np.random`. Used when ``selection`` ==
#     'random'.
#
# selection : str, default 'cyclic'
#     If set to 'random', a random coefficient is updated every iteration
#     rather than looping over features sequentially by default. This
#     (setting to 'random') often leads to significantly faster convergence
#     especially when tol is higher than 1e-4.
#
# Attributes
# ----------
# coef_ : array, shape (n_features,) | (n_targets, n_features)
#     parameter vector (w in the cost function formula)
#
# sparse_coef_ : scipy.sparse matrix, shape (n_features, 1) |             (n_targets, n_features)
#     ``sparse_coef_`` is a readonly property derived from ``coef_``
#
# intercept_ : float | array, shape (n_targets,)
#     independent term in decision function.
#
# n_iter_ : array-like, shape (n_targets,)
#     number of iterations run by the coordinate descent solver to reach
#     the specified tolerance.
#
# Examples
# --------
# >>> from sklearn.linear_model import ElasticNet
# >>> from sklearn.datasets import make_regression
#
# >>> X, y = make_regression(n_features=2, random_state=0)
# >>> regr = ElasticNet(random_state=0)
# >>> regr.fit(X, y)
# ElasticNet(random_state=0)
# >>> print(regr.coef_)
# [18.83816048 64.55968825]
# >>> print(regr.intercept_)
# 1.451...
# >>> print(regr.predict([[0, 0]]))
# [1.451...]
#
#
# Notes
# -----
# To avoid unnecessary memory duplication the X argument of the fit method
# should be directly passed as a Fortran-contiguous numpy array.
#
# See also
# --------
# ElasticNetCV : Elastic net model with best model selection by
#     cross-validation.
# SGDRegressor: implements elastic net regression with incremental training.
# SGDClassifier: implements logistic regression with elastic net penalty
#     (``SGDClassifier(loss="log", penalty="elasticnet")``).
# File:           ~/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py
# Type:           ABCMeta
# Subclasses:     Lasso

# %%
enet_cv_model.alpha_
# Out:
# 1.0

# %%
enet_tuned = ElasticNet(alpha = enet_cv_model.alpha_).fit(X_train, y_train)
y_pred = enet_tuned.predict(X_test)
np.sqrt(mean_squared_error(y_test, y_pred))
# Out:
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7212874.4082818115, tolerance: 3956.6756074595623
#   positive)
# 486.1834215724992

# %%
#gridsearch ile model tuning

# %%
enet_params = {"l1_ratio": [0.1,0.4,0.5,0.6,0.8,1],
              "alpha":[0.1,0.01,0.001,0.2,0.3,0.5,0.8,0.9,1]}

# %%
enet_model = ElasticNet().fit(X, y)

# %%
from sklearn.model_selection import GridSearchCV

# %%
gs_cv_enet = GridSearchCV(enet_model, enet_params, cv = 10).fit(X, y)
# Out:
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 36605.67359692231, tolerance: 5077.3603631314545
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 337994.0544420257, tolerance: 4957.926101024957
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 433884.6163691953, tolerance: 4119.306728055035
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1084680.4656932484, tolerance: 4838.771789136585
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2015413.8449163027, tolerance: 4652.294266532092
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 152373.3727405481, tolerance: 4816.155704333359
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 38320.32652374357, tolerance: 4637.712860074581
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 71135.35431947932, tolerance: 4976.191260952606
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 223241.29322135076, tolerance: 4971.958809825996
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 87912.85239684582, tolerance: 4912.860355045331
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 40111.766285948455, tolerance: 5077.3603631314545
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 310349.98817801103, tolerance: 4957.926101024957
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 35481.88305874169, tolerance: 4119.306728055035
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 151147.7505612485, tolerance: 4838.771789136585
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 332235.1636890955, tolerance: 4652.294266532092
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 426796.2919826545, tolerance: 4816.155704333359
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 69181.5330606848, tolerance: 4637.712860074581
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 52765.60998342931, tolerance: 4976.191260952606
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 66795.32668462023, tolerance: 4971.958809825996
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 132025.37419676408, tolerance: 4912.860355045331
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4900363.708874716, tolerance: 5077.3603631314545
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9327052.07392842, tolerance: 4957.926101024957
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7287912.827086116, tolerance: 4119.306728055035
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8812933.808367617, tolerance: 4838.771789136585
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9225085.742004585, tolerance: 4652.294266532092
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8762014.855521457, tolerance: 4816.155704333359
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4205664.328731409, tolerance: 4637.712860074581
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6224248.064214657, tolerance: 4976.191260952606
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8773082.418769628, tolerance: 4971.958809825996
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8727189.351181138, tolerance: 4912.860355045331
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10781265.350500217, tolerance: 5077.3603631314545
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11616239.618712746, tolerance: 4957.926101024957
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10159921.062940259, tolerance: 4119.306728055035
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11107861.738698898, tolerance: 4838.771789136585
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11180281.340134535, tolerance: 4652.294266532092
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11273908.570100786, tolerance: 4816.155704333359
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8861642.689753333, tolerance: 4637.712860074581
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10562656.596107967, tolerance: 4976.191260952606
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10762390.016604252, tolerance: 4971.958809825996
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11028156.795292258, tolerance: 4912.860355045331
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10535813.297404688, tolerance: 5077.3603631314545
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11482639.516570818, tolerance: 4957.926101024957
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10002379.54199479, tolerance: 4119.306728055035
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10959900.756361978, tolerance: 4838.771789136585
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11056015.827062646, tolerance: 4652.294266532092
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11136498.879461335, tolerance: 4816.155704333359
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8687546.393328154, tolerance: 4637.712860074581
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10373677.144246507, tolerance: 4976.191260952606
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10628538.855774611, tolerance: 4971.958809825996
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10886096.309879871, tolerance: 4912.860355045331
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10490174.33434582, tolerance: 5077.3603631314545
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11463131.24998213, tolerance: 4957.926101024957
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9983771.351622203, tolerance: 4119.306728055035
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10938529.920092843, tolerance: 4838.771789136585
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11035025.045307064, tolerance: 4652.294266532092
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11111614.668608064, tolerance: 4816.155704333359
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8647229.469735438, tolerance: 4637.712860074581
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10341005.033311212, tolerance: 4976.191260952606
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10606190.75878715, tolerance: 4971.958809825996
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10865200.916583698, tolerance: 4912.860355045331
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10452841.530105859, tolerance: 5077.3603631314545
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11449867.328775136, tolerance: 4957.926101024957
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9973686.468182294, tolerance: 4119.306728055035
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10924443.895470751, tolerance: 4838.771789136585
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11019255.516325185, tolerance: 4652.294266532092
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11092472.934250493, tolerance: 4816.155704333359
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8610112.87726825, tolerance: 4637.712860074581
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10314298.442083506, tolerance: 4976.191260952606
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10589595.44587744, tolerance: 4971.958809825996
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10851081.325430395, tolerance: 4912.860355045331
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10387872.09310656, tolerance: 5077.3603631314545
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11434263.846639251, tolerance: 4957.926101024957
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9968444.087917391, tolerance: 4119.306728055035
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10907631.567835769, tolerance: 4838.771789136585
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10996961.1322761, tolerance: 4652.294266532092
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11064798.384045677, tolerance: 4816.155704333359
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8533834.613341218, tolerance: 4637.712860074581
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10265259.931528771, tolerance: 4976.191260952606
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10566614.449007336, tolerance: 4971.958809825996
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10834900.883012392, tolerance: 4912.860355045331
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10312694.766882371, tolerance: 5077.3603631314545
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11424083.55779894, tolerance: 4957.926101024957
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9970403.75960579, tolerance: 4119.306728055035
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10897578.795184672, tolerance: 4838.771789136585
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10980345.682353772, tolerance: 4652.294266532092
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11043821.148669887, tolerance: 4816.155704333359
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8428150.633667408, tolerance: 4637.712860074581
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10200328.25627118, tolerance: 4976.191260952606
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10549911.168069081, tolerance: 4971.958809825996
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10826303.90388056, tolerance: 4912.860355045331
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 14483.65960783884, tolerance: 5077.3603631314545
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 243633.29278029874, tolerance: 4957.926101024957
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 54228.66014273465, tolerance: 4119.306728055035
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 323371.7770102024, tolerance: 4838.771789136585
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 686919.3615304008, tolerance: 4652.294266532092
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 50460.409966655076, tolerance: 4816.155704333359
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 19102.786688141525, tolerance: 4637.712860074581
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 28202.88032571599, tolerance: 4976.191260952606
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 365192.46929126605, tolerance: 4971.958809825996
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 173818.1047700122, tolerance: 4912.860355045331
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9600.208741925657, tolerance: 5077.3603631314545
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 82712.04207829386, tolerance: 4957.926101024957
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 44192.29902122542, tolerance: 4838.771789136585
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 317747.31289898977, tolerance: 4652.294266532092
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 29049.34840438515, tolerance: 4816.155704333359
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15160.847102496773, tolerance: 4637.712860074581
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 19743.214253112674, tolerance: 4976.191260952606
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 263692.19378973916, tolerance: 4971.958809825996
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 87778.75745100155, tolerance: 4912.860355045331
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6235.684008784592, tolerance: 5077.3603631314545
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5577.583369880915, tolerance: 4957.926101024957
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 23708.50782533735, tolerance: 4652.294266532092
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 16337.479319177568, tolerance: 4816.155704333359
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 12832.175532706082, tolerance: 4637.712860074581
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15209.335885986686, tolerance: 4976.191260952606
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 13468.328430537134, tolerance: 4971.958809825996
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5440.290385313332, tolerance: 5077.3603631314545
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 19229.063310191035, tolerance: 4816.155704333359
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10739.615620583296, tolerance: 4637.712860074581
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 13023.359426505864, tolerance: 4976.191260952606
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5194.054289687425, tolerance: 5077.3603631314545
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5518.63608276844, tolerance: 4816.155704333359
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10250.040722686797, tolerance: 4637.712860074581
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 12371.203225817531, tolerance: 4976.191260952606
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9820.372265059501, tolerance: 4637.712860074581
#   positive)
# /Users/mvahit/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 16226.579207904637, tolerance: 4976.191260952606
#   positive)

# %%
gs_cv_enet.best_params_
# Out:
# {'alpha': 1, 'l1_ratio': 0.1}

# %%
enet_tuned = ElasticNet(**gs_cv_enet.best_params_).fit(X, y)

# %%
y_pred = enet_tuned.predict(X)
np.sqrt(mean_squared_error(y, y_pred))
# Out:
# 330.88750023306653

# %%
y_pred = enet_tuned.predict(X_test)
np.sqrt(mean_squared_error(y_test, y_pred))
# Out:
# 414.2984572484783

# %%
#Model, Tahmin Başarı, model tuning
